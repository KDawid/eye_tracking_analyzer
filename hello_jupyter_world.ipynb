# %%
import polars as pl

# %%
df = pl.DataFrame({"a": [0], "b": [1]})
print(df)
print("Hello World!")
# Out:
# shape: (1, 2)
# ┌─────┬─────┐
# │ a   ┆ b   │
# │ --- ┆ --- │
# │ i64 ┆ i64 │
# ╞═════╪═════╡
# │ 0   ┆ 1   │
# └─────┴─────┘
# Hello World!
